# %%
print("hello world!!")
# Out:
# hello world!!

# %% [markdown]
# This is a Markdown cell. When it "runs" it will look like content displayed in a webpage.

# %% [markdown]
# **Jupyter Notebook**: is a collection of interleaved markdown and code cells that collectively tell a *story* about a data science problem and solution.

# %% [markdown]
# In the following code cell, we are going to produce a line chart of the first 6 squared numbers.

# %%
import matplotlib.pyplot as plt

# we need some data
x = [0, 1, 2, 3, 4, 5]
x_squared = [0, 1, 4, 9, 16, 25]

plt.plot(x, x_squared)
plt.show() # to show a plot inline in a Jupyter Notebook
# instead of saving it to a file

# %% [markdown]
# The chart above shows that as x gets larger, so does its squares.

# %% [markdown]
# # Level One Header
# ## Level Two Header
# There are 6 header levels. Headers are used to organize your notebook into sections. Use level 1 headers for the big divisions of the notebook, and smaller levels for subsections.
#
# This is paragraph text
#
# Hard break is two new lines
#
# Soft break is two spaces plus a new line
# This is the next line

# %% [markdown]
# ## Formatting
# We can **bold** or __bold__
#
# We can *italicize* or _italicize_
#
# We can ~~strikethrough~~
#
# We can use block quotes (quoting/using large text from another source or for drawing attention to text):
# >This is a multi
# line block
# quote :)
#
# We can syntax highlight code, either inline with the text: `x = 5` or as a block (for longer code):
# ```python
# for i in range(5):
#     print(i)
# ```

# %% [markdown]
# ## Lists
# There are two types of lists: unordered and ordered lists
#
# Unordered lists:
# * Item A
# * Item B
# * Item C
#
# Ordered lists:
# 1. Item 1
# 1. Item 2
# 1. Item 3
#
# We can mix list types and nest them to create sublists:
# 1. Item 1
#     * Item A
#     * Item B
# 1. Item 2
#     1. Item C
#     1. Item D
# 1. Item 3

# %% [markdown]
# ## Links
# We can simply paste a link or we can make inline with text
#
# https://www.markdowntutorial.com/
#
# I recommend people complete [this](https://www.markdowntutorial.com/) markdown tutorial

# %% [markdown]
# ## Images
# Images are of the form `![alt text](path to the image)`
#
# Path to the image can be:
# * A file path, such as one on your file system
# * A URL (link address to somewhere on the web)
#     * Example:
#
# ![an image that says i heart markdown](https://cdn.foliovision.com/images/2017/03/i-love-markdown.png)
#
#
# We can use HTML to resize the image:
# <img src="https://cdn.foliovision.com/images/2017/03/i-love-markdown.png" width="200"/>

# %% [markdown]
# ## Tables
# Let's create a table for the China city population
#
# City|Population|Class
# -|-|-
# Shanghai|24.8|Large
# Beijing|21.1|Large
# Hangzhou|7.9|Medium

# %% [markdown]
# ## Latex's Math Mode
# Latex is a mathematical typesetting language for technical documents and formulas
#
# Latex's math mode is used for typesetting formulas. Use a single dollar sign to enter inline math mode: $y = mx + b$
#
# Use 2 dollar signs to enter block (centered) math mode: $$y = mx + b$$
#
# Here are some common features and commands of Latex:
# Subscripts: $x_i x_{i + 1}$
# Superscripts: $x^i x^{i + 1}$
# Symbols over characters: $\overline{x + 1} \widehat{y + 1}$
# Special symbols: $\mu \sigma \pi \times \cup \cap \forall$
# Fractions: $\frac{1}{x + y + z}$
# Square roots: $\sqrt{2}$
# Summations: $\sum_{i = 1}^n x_i$
#
# Check out this cheat sheet for more Latex commands: https://users.dickinson.edu/~richesod/latex/latexcheatsheet.pdf

# %% [markdown]
# ## Warm up Task
# Quadratic formula: $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$

# %%
import math

def quadratic_formula(a, b, c):
    discriminant = math.sqrt(b ** 2 - 4 * a * c)
    solution1 = (-b - discriminant) / (2 * a)    
    solution2 = (-b + discriminant) / (2 * a)    
    return solution1, solution2
